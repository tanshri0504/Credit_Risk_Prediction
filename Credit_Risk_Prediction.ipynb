# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
dt = pd.read_csv("../DataSets/credit_record.csv")

# %%
de = pd.read_csv("../DataSets/application_record.csv")

# %%
df = pd.merge(dt,de,on='ID')

# %%
df
# Out:
#              ID  MONTHS_BALANCE STATUS CODE_GENDER FLAG_OWN_CAR  \
# 0       5008804               0      C           M            Y
# 1       5008804              -1      C           M            Y
# 2       5008804              -2      C           M            Y
# 3       5008804              -3      C           M            Y
# 4       5008804              -4      C           M            Y
# ...         ...             ...    ...         ...          ...
# 777710  5150487             -25      C           M            Y
# 777711  5150487             -26      C           M            Y
# 777712  5150487             -27      C           M            Y
# 777713  5150487             -28      C           M            Y
# 777714  5150487             -29      C           M            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL NAME_INCOME_TYPE  \
# 0                    Y             0          427500.0          Working
# 1                    Y             0          427500.0          Working
# 2                    Y             0          427500.0          Working
# 3                    Y             0          427500.0          Working
# 4                    Y             0          427500.0          Working
# ...                ...           ...               ...              ...
# 777710               N             0          202500.0          Working
# 777711               N             0          202500.0          Working
# 777712               N             0          202500.0          Working
# 777713               N             0          202500.0          Working
# 777714               N             0          202500.0          Working
#
#                   NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 0                    Higher education     Civil marriage   Rented apartment
# 1                    Higher education     Civil marriage   Rented apartment
# 2                    Higher education     Civil marriage   Rented apartment
# 3                    Higher education     Civil marriage   Rented apartment
# 4                    Higher education     Civil marriage   Rented apartment
# ...                               ...                ...                ...
# 777710  Secondary / secondary special            Married  House / apartment
# 777711  Secondary / secondary special            Married  House / apartment
# 777712  Secondary / secondary special            Married  House / apartment
# 777713  Secondary / secondary special            Married  House / apartment
# 777714  Secondary / secondary special            Married  House / apartment
#
#         DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  \
# 0           -12005          -4542           1                1           0
# 1           -12005          -4542           1                1           0
# 2           -12005          -4542           1                1           0
# 3           -12005          -4542           1                1           0
# 4           -12005          -4542           1                1           0
# ...            ...            ...         ...              ...         ...
# 777710      -19398          -2166           1                0           0
# 777711      -19398          -2166           1                0           0
# 777712      -19398          -2166           1                0           0
# 777713      -19398          -2166           1                0           0
# 777714      -19398          -2166           1                0           0
#
#         FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS
# 0                0             NaN              2.0
# 1                0             NaN              2.0
# 2                0             NaN              2.0
# 3                0             NaN              2.0
# 4                0             NaN              2.0
# ...            ...             ...              ...
# 777710           0         Drivers              2.0
# 777711           0         Drivers              2.0
# 777712           0         Drivers              2.0
# 777713           0         Drivers              2.0
# 777714           0         Drivers              2.0
#
# [777715 rows x 20 columns]

# %%
df.rename(columns={
    'AMT_INCOME_TOTAL': 'Annual_Income',
    'CNT_FAM_MEMBERS': 'Family_Member_Count',
    'DAYS_BIRTH': 'Age_Days',
    'DAYS_EMPLOYED': 'Employment_Days',
    'NAME_INCOME_TYPE': 'Income_Type',
    'OCCUPATION_TYPE': 'Occupation_Type'},inplace=True)

# %%
df
# Out:
#              ID  MONTHS_BALANCE STATUS CODE_GENDER FLAG_OWN_CAR  \
# 0       5008804               0      C           M            Y
# 1       5008804              -1      C           M            Y
# 2       5008804              -2      C           M            Y
# 3       5008804              -3      C           M            Y
# 4       5008804              -4      C           M            Y
# ...         ...             ...    ...         ...          ...
# 777710  5150487             -25      C           M            Y
# 777711  5150487             -26      C           M            Y
# 777712  5150487             -27      C           M            Y
# 777713  5150487             -28      C           M            Y
# 777714  5150487             -29      C           M            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  Annual_Income Income_Type  \
# 0                    Y             0       427500.0     Working
# 1                    Y             0       427500.0     Working
# 2                    Y             0       427500.0     Working
# 3                    Y             0       427500.0     Working
# 4                    Y             0       427500.0     Working
# ...                ...           ...            ...         ...
# 777710               N             0       202500.0     Working
# 777711               N             0       202500.0     Working
# 777712               N             0       202500.0     Working
# 777713               N             0       202500.0     Working
# 777714               N             0       202500.0     Working
#
#                   NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 0                    Higher education     Civil marriage   Rented apartment
# 1                    Higher education     Civil marriage   Rented apartment
# 2                    Higher education     Civil marriage   Rented apartment
# 3                    Higher education     Civil marriage   Rented apartment
# 4                    Higher education     Civil marriage   Rented apartment
# ...                               ...                ...                ...
# 777710  Secondary / secondary special            Married  House / apartment
# 777711  Secondary / secondary special            Married  House / apartment
# 777712  Secondary / secondary special            Married  House / apartment
# 777713  Secondary / secondary special            Married  House / apartment
# 777714  Secondary / secondary special            Married  House / apartment
#
#         Age_Days  Employment_Days  FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  \
# 0         -12005            -4542           1                1           0
# 1         -12005            -4542           1                1           0
# 2         -12005            -4542           1                1           0
# 3         -12005            -4542           1                1           0
# 4         -12005            -4542           1                1           0
# ...          ...              ...         ...              ...         ...
# 777710    -19398            -2166           1                0           0
# 777711    -19398            -2166           1                0           0
# 777712    -19398            -2166           1                0           0
# 777713    -19398            -2166           1                0           0
# 777714    -19398            -2166           1                0           0
#
#         FLAG_EMAIL Occupation_Type  Family_Member_Count
# 0                0             NaN                  2.0
# 1                0             NaN                  2.0
# 2                0             NaN                  2.0
# 3                0             NaN                  2.0
# 4                0             NaN                  2.0
# ...            ...             ...                  ...
# 777710           0         Drivers                  2.0
# 777711           0         Drivers                  2.0
# 777712           0         Drivers                  2.0
# 777713           0         Drivers                  2.0
# 777714           0         Drivers                  2.0
#
# [777715 rows x 20 columns]

# %%
df.isnull().sum()
# Out:
# ID                          0
# MONTHS_BALANCE              0
# STATUS                      0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# Annual_Income               0
# Income_Type                 0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# Age_Days                    0
# Employment_Days             0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# Occupation_Type        240048
# Family_Member_Count         0
# dtype: int64

# %%
df.Occupation_Type.unique()
# Out:
# array([nan, 'Security staff', 'Sales staff', 'Accountants', 'Laborers',
#        'Managers', 'Drivers', 'Core staff', 'High skill tech staff',
#        'Cleaning staff', 'Private service staff', 'Cooking staff',
#        'Low-skill Laborers', 'Medicine staff', 'Secretaries',
#        'Waiters/barmen staff', 'HR staff', 'Realty agents', 'IT staff'],
#       dtype=object)

# %%
df.Occupation_Type.mode()
# Out:
# 0    Laborers
# Name: Occupation_Type, dtype: object

# %%
df.Occupation_Type = df.Occupation_Type.fillna('Laborers')

# %%
df.STATUS.unique()
# Out:
# array(['C', '1', '0', 'X', '5', '4', '3', '2'], dtype=object)

# %%
df['Credit_Risk'] = df['STATUS']

# %%
df.Occupation_Type.value_counts()
# Out:
# Occupation_Type
# Laborers                 371620
# Core staff                77112
# Sales staff               70362
# Managers                  67738
# Drivers                   47678
# High skill tech staff     31768
# Accountants               27223
# Medicine staff            26691
# Cooking staff             13416
# Security staff            12400
# Cleaning staff            11399
# Private service staff      6714
# Low-skill Laborers         3623
# Secretaries                3149
# Waiters/barmen staff       2557
# HR staff                   1686
# IT staff                   1319
# Realty agents              1260
# Name: count, dtype: int64

# %%
df.Credit_Risk = df.Credit_Risk.replace(['2','3','4','5'],1)
df.Credit_Risk = df.Credit_Risk.replace(['1','0','C','X'],0)
# Out:
# /var/folders/sr/4qm4jpdx6l56zmjmgrgd_2yw0000gn/T/ipykernel_7557/3118559122.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.Credit_Risk = df.Credit_Risk.replace(['1','0','C','X'],0)

# %%
df.Credit_Risk.unique()
# Out:
# array([0, 1])

# %% [markdown]
# ## EDA

# %%
## 1)What is the distribution of the Credit_Risk variable (Good (0) vs Bad (1))?

sb.countplot(x= df.Credit_Risk)
plt.title("Distribution of Credit Risk")
plt.show()
df.Credit_Risk.value_counts()
# Out:
# Credit_Risk
# 0    774887
# 1      2828
# Name: count, dtype: int64

# %% [markdown]
# The dataset is highly imbalanced, with the majority of customers classified as Good credit risk (0) and only a very small proportion classified as Bad credit risk (1).

# %%
## 2) Which STATUS category occurs most frequently?

sb.countplot(x=df.STATUS)
plt.title("STATUS Category Distribution")
plt.show()
df.STATUS.value_counts()
# Out:
# STATUS
# C    329536
# 0    290654
# X    145950
# 1      8747
# 5      1527
# 2       801
# 3       286
# 4       214
# Name: count, dtype: int64

# %% [markdown]
# The most frequent STATUS category is “C”, indicating that the majority of records fall under this status compared to all other categories.

# %%
## 3)What is the distribution of Annual Income?

plt.figure(figsize=([10,5]))
sb.histplot(x =df.Annual_Income,bins=20)
plt.title("Annual Income Distribution")
plt.show()

# %% [markdown]
# The Annual Income distribution appears to be right-skewed, with most individuals having lower to moderate incomes and a smaller number earning very high incomes.

# %%
df['Age_Days'] = abs(df['Age_Days']) // 365
df['Employment_Days'] = abs(df['Employment_Days']) // 365
df
# Out:
#              ID  MONTHS_BALANCE STATUS CODE_GENDER FLAG_OWN_CAR  \
# 0       5008804               0      C           M            Y
# 1       5008804              -1      C           M            Y
# 2       5008804              -2      C           M            Y
# 3       5008804              -3      C           M            Y
# 4       5008804              -4      C           M            Y
# ...         ...             ...    ...         ...          ...
# 777710  5150487             -25      C           M            Y
# 777711  5150487             -26      C           M            Y
# 777712  5150487             -27      C           M            Y
# 777713  5150487             -28      C           M            Y
# 777714  5150487             -29      C           M            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  Annual_Income Income_Type  \
# 0                    Y             0       427500.0     Working
# 1                    Y             0       427500.0     Working
# 2                    Y             0       427500.0     Working
# 3                    Y             0       427500.0     Working
# 4                    Y             0       427500.0     Working
# ...                ...           ...            ...         ...
# 777710               N             0       202500.0     Working
# 777711               N             0       202500.0     Working
# 777712               N             0       202500.0     Working
# 777713               N             0       202500.0     Working
# 777714               N             0       202500.0     Working
#
#                   NAME_EDUCATION_TYPE  ...  NAME_HOUSING_TYPE Age_Days  \
# 0                    Higher education  ...   Rented apartment       32
# 1                    Higher education  ...   Rented apartment       32
# 2                    Higher education  ...   Rented apartment       32
# 3                    Higher education  ...   Rented apartment       32
# 4                    Higher education  ...   Rented apartment       32
# ...                               ...  ...                ...      ...
# 777710  Secondary / secondary special  ...  House / apartment       53
# 777711  Secondary / secondary special  ...  House / apartment       53
# 777712  Secondary / secondary special  ...  House / apartment       53
# 777713  Secondary / secondary special  ...  House / apartment       53
# 777714  Secondary / secondary special  ...  House / apartment       53
#
#         Employment_Days  FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  \
# 0                    12           1                1           0           0
# 1                    12           1                1           0           0
# 2                    12           1                1           0           0
# 3                    12           1                1           0           0
# 4                    12           1                1           0           0
# ...                 ...         ...              ...         ...         ...
# 777710                5           1                0           0           0
# 777711                5           1                0           0           0
# 777712                5           1                0           0           0
# 777713                5           1                0           0           0
# 777714                5           1                0           0           0
#
#         Occupation_Type Family_Member_Count  Credit_Risk
# 0              Laborers                 2.0            0
# 1              Laborers                 2.0            0
# 2              Laborers                 2.0            0
# 3              Laborers                 2.0            0
# 4              Laborers                 2.0            0
# ...                 ...                 ...          ...
# 777710          Drivers                 2.0            0
# 777711          Drivers                 2.0            0
# 777712          Drivers                 2.0            0
# 777713          Drivers                 2.0            0
# 777714          Drivers                 2.0            0
#
# [777715 rows x 21 columns]

# %%
## 4) What is the age distribution of customers?

plt.figure(figsize=[8,5])
sb.histplot(df.Age_Days,bins=15)
plt.title("Age Distribution of Customers")
plt.show()

# %% [markdown]
# The customer age distribution shows that most customers belong to the middle-age group, with fewer very young or older customers.

# %%
## 5) How is Employment Length distributed?

plt.figure(figsize=[8,5])
sb.histplot(df.Employment_Days,bins=10)
plt.title("Employment Length Distribution")
plt.show()

# %% [markdown]
# The Employment Length distribution indicates that most customers have shorter to moderate employment durations, while fewer customers have very long employment histories.

# %%
## 6) What is the distribution of Family Member Count?

sb.countplot(x = df.Family_Member_Count)
plt.title('Distribution of Family Member Count')
plt.show()

# %% [markdown]
# The distribution of Family Member Count shows that most customers belong to small families with fewer family members.

# %%
## 7) How are categorical features distributed?

categorical = ['CODE_GENDER','NAME_EDUCATION_TYPE','NAME_FAMILY_STATUS','NAME_HOUSING_TYPE','Income_Type',
               'Occupation_Type','STATUS','FLAG_OWN_REALTY','FLAG_OWN_CAR']

for col in categorical:
    plt.figure(figsize=[15,5])
    sb.countplot(x = df[col])
    plt.show()

# %% [markdown]
# The categorical features show uneven distributions, where certain categories dominate each variable while some categories have comparatively very few records.

# %%
## 8) How does Annual Income vary between good (0) and bad (1) credit customers?

sb.boxplot(x=df.Credit_Risk , y=df.Annual_Income)
plt.title("Annual Income by Credit Risk")
plt.show()

# %% [markdown]
# The boxplot suggests that Annual Income levels are fairly similar for both good and bad credit customers, with some income outliers present in each group.

# %%
## 9)Are certain Occupation Types associated with higher bad credit risk?

plt.figure(figsize=[15,8])
sb.barplot(x=df.Occupation_Type , y=df.Credit_Risk)
plt.xticks(rotation=90)
plt.title("Occupation Type vs Credit Risk")
plt.show()

# %% [markdown]
# Certain occupation types show relatively higher average bad credit risk, indicating that credit risk may vary depending on the customer’s occupation category.

# %%
## 10) What is the correlation between numerical features?

df.corr(numeric_only=True)
# Out:
#                            ID  MONTHS_BALANCE  CNT_CHILDREN  Annual_Income  \
# ID                   1.000000        0.005007      0.026269      -0.027597
# MONTHS_BALANCE       0.005007        1.000000      0.000913       0.001831
# CNT_CHILDREN         0.026269        0.000913      1.000000       0.039304
# Annual_Income       -0.027597        0.001831      0.039304       1.000000
# Age_Days            -0.041938       -0.035813     -0.356017      -0.081093
# Employment_Days     -0.025921       -0.005456     -0.231170      -0.180334
# FLAG_MOBIL                NaN             NaN           NaN            NaN
# FLAG_WORK_PHONE      0.084800        0.001529      0.042226      -0.021229
# FLAG_PHONE           0.006346       -0.005120     -0.018882       0.018687
# FLAG_EMAIL          -0.056083        0.005288      0.015726       0.085776
# Family_Member_Count  0.027375       -0.006276      0.892079       0.031379
# Credit_Risk          0.010690       -0.004405     -0.000705       0.003267
#
#                      Age_Days  Employment_Days  FLAG_MOBIL  FLAG_WORK_PHONE  \
# ID                  -0.041938        -0.025921         NaN         0.084800
# MONTHS_BALANCE      -0.035813        -0.005456         NaN         0.001529
# CNT_CHILDREN        -0.356017        -0.231170         NaN         0.042226
# Annual_Income       -0.081093        -0.180334         NaN        -0.021229
# Age_Days             1.000000         0.617057         NaN        -0.181275
# Employment_Days      0.617057         1.000000         NaN        -0.243825
# FLAG_MOBIL                NaN              NaN         NaN              NaN
# FLAG_WORK_PHONE     -0.181275        -0.243825         NaN         1.000000
# FLAG_PHONE           0.026586        -0.012788         NaN         0.312552
# FLAG_EMAIL          -0.100706        -0.083933         NaN        -0.037991
# Family_Member_Count -0.327615        -0.229471         NaN         0.060183
# Credit_Risk          0.005234         0.003170         NaN         0.007412
#
#                      FLAG_PHONE  FLAG_EMAIL  Family_Member_Count  Credit_Risk
# ID                     0.006346   -0.056083             0.027375     0.010690
# MONTHS_BALANCE        -0.005120    0.005288            -0.006276    -0.004405
# CNT_CHILDREN          -0.018882    0.015726             0.892079    -0.000705
# Annual_Income          0.018687    0.085776             0.031379     0.003267
# Age_Days               0.026586   -0.100706            -0.327615     0.005234
# Employment_Days       -0.012788   -0.083933            -0.229471     0.003170
# FLAG_MOBIL                  NaN         NaN                  NaN          NaN
# FLAG_WORK_PHONE        0.312552   -0.037991             0.060183     0.007412
# FLAG_PHONE             1.000000    0.011901            -0.007824     0.007213
# FLAG_EMAIL             0.011901    1.000000             0.012540    -0.003054
# Family_Member_Count   -0.007824    0.012540             1.000000    -0.001874
# Credit_Risk            0.007213   -0.003054            -0.001874     1.000000

# %% [markdown]
# The correlation matrix indicates that most numerical features have weak correlations with each other, suggesting limited linear relationships among the variables.

# %%
## 11) Are there extreme outliers in Annual Income?

sb.boxplot(df.Annual_Income)
plt.show()

# %% [markdown]
# The boxplot reveals the presence of extreme outliers in Annual Income, with a few customers earning significantly higher incomes than the majority.

# %%
## 12) How does credit risk vary by Income Type?

plt.figure(figsize=[15,8])
sb.barplot(x=df.Income_Type , y=df.Credit_Risk)
plt.title("Income Type by Credit Risk")
plt.show()

# %% [markdown]
# Credit risk varies across different income types, with some income categories showing a comparatively higher proportion of bad credit risk customers.

# %% [markdown]
# ## ML

# %%
df
# Out:
#              ID  MONTHS_BALANCE STATUS CODE_GENDER FLAG_OWN_CAR  \
# 0       5008804               0      C           M            Y
# 1       5008804              -1      C           M            Y
# 2       5008804              -2      C           M            Y
# 3       5008804              -3      C           M            Y
# 4       5008804              -4      C           M            Y
# ...         ...             ...    ...         ...          ...
# 777710  5150487             -25      C           M            Y
# 777711  5150487             -26      C           M            Y
# 777712  5150487             -27      C           M            Y
# 777713  5150487             -28      C           M            Y
# 777714  5150487             -29      C           M            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  Annual_Income Income_Type  \
# 0                    Y             0       427500.0     Working
# 1                    Y             0       427500.0     Working
# 2                    Y             0       427500.0     Working
# 3                    Y             0       427500.0     Working
# 4                    Y             0       427500.0     Working
# ...                ...           ...            ...         ...
# 777710               N             0       202500.0     Working
# 777711               N             0       202500.0     Working
# 777712               N             0       202500.0     Working
# 777713               N             0       202500.0     Working
# 777714               N             0       202500.0     Working
#
#                   NAME_EDUCATION_TYPE  ...  NAME_HOUSING_TYPE Age_Days  \
# 0                    Higher education  ...   Rented apartment       32
# 1                    Higher education  ...   Rented apartment       32
# 2                    Higher education  ...   Rented apartment       32
# 3                    Higher education  ...   Rented apartment       32
# 4                    Higher education  ...   Rented apartment       32
# ...                               ...  ...                ...      ...
# 777710  Secondary / secondary special  ...  House / apartment       53
# 777711  Secondary / secondary special  ...  House / apartment       53
# 777712  Secondary / secondary special  ...  House / apartment       53
# 777713  Secondary / secondary special  ...  House / apartment       53
# 777714  Secondary / secondary special  ...  House / apartment       53
#
#         Employment_Days  FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  \
# 0                    12           1                1           0           0
# 1                    12           1                1           0           0
# 2                    12           1                1           0           0
# 3                    12           1                1           0           0
# 4                    12           1                1           0           0
# ...                 ...         ...              ...         ...         ...
# 777710                5           1                0           0           0
# 777711                5           1                0           0           0
# 777712                5           1                0           0           0
# 777713                5           1                0           0           0
# 777714                5           1                0           0           0
#
#         Occupation_Type Family_Member_Count  Credit_Risk
# 0              Laborers                 2.0            0
# 1              Laborers                 2.0            0
# 2              Laborers                 2.0            0
# 3              Laborers                 2.0            0
# 4              Laborers                 2.0            0
# ...                 ...                 ...          ...
# 777710          Drivers                 2.0            0
# 777711          Drivers                 2.0            0
# 777712          Drivers                 2.0            0
# 777713          Drivers                 2.0            0
# 777714          Drivers                 2.0            0
#
# [777715 rows x 21 columns]

# %%
df=df.drop(['ID','STATUS','CODE_GENDER','CNT_CHILDREN','Age_Days','FLAG_MOBIL','FLAG_WORK_PHONE','FLAG_PHONE','FLAG_EMAIL'], axis=1)

# %%
df
# Out:
#         MONTHS_BALANCE FLAG_OWN_CAR FLAG_OWN_REALTY  Annual_Income  \
# 0                    0            Y               Y       427500.0
# 1                   -1            Y               Y       427500.0
# 2                   -2            Y               Y       427500.0
# 3                   -3            Y               Y       427500.0
# 4                   -4            Y               Y       427500.0
# ...                ...          ...             ...            ...
# 777710             -25            Y               N       202500.0
# 777711             -26            Y               N       202500.0
# 777712             -27            Y               N       202500.0
# 777713             -28            Y               N       202500.0
# 777714             -29            Y               N       202500.0
#
#        Income_Type            NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0          Working               Higher education     Civil marriage
# 1          Working               Higher education     Civil marriage
# 2          Working               Higher education     Civil marriage
# 3          Working               Higher education     Civil marriage
# 4          Working               Higher education     Civil marriage
# ...            ...                            ...                ...
# 777710     Working  Secondary / secondary special            Married
# 777711     Working  Secondary / secondary special            Married
# 777712     Working  Secondary / secondary special            Married
# 777713     Working  Secondary / secondary special            Married
# 777714     Working  Secondary / secondary special            Married
#
#         NAME_HOUSING_TYPE  Employment_Days Occupation_Type  \
# 0        Rented apartment               12        Laborers
# 1        Rented apartment               12        Laborers
# 2        Rented apartment               12        Laborers
# 3        Rented apartment               12        Laborers
# 4        Rented apartment               12        Laborers
# ...                   ...              ...             ...
# 777710  House / apartment                5         Drivers
# 777711  House / apartment                5         Drivers
# 777712  House / apartment                5         Drivers
# 777713  House / apartment                5         Drivers
# 777714  House / apartment                5         Drivers
#
#         Family_Member_Count  Credit_Risk
# 0                       2.0            0
# 1                       2.0            0
# 2                       2.0            0
# 3                       2.0            0
# 4                       2.0            0
# ...                     ...          ...
# 777710                  2.0            0
# 777711                  2.0            0
# 777712                  2.0            0
# 777713                  2.0            0
# 777714                  2.0            0
#
# [777715 rows x 12 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()

# %%
df.FLAG_OWN_CAR=label.fit_transform(df.FLAG_OWN_CAR)
df.FLAG_OWN_REALTY=label.fit_transform(df.FLAG_OWN_REALTY)
df.Income_Type=label.fit_transform(df.Income_Type)
df.NAME_EDUCATION_TYPE=label.fit_transform(df.NAME_EDUCATION_TYPE)
df.NAME_FAMILY_STATUS=label.fit_transform(df.NAME_FAMILY_STATUS)
df.NAME_HOUSING_TYPE=label.fit_transform(df.NAME_HOUSING_TYPE)
df.Occupation_Type=label.fit_transform(df.Occupation_Type)

# %%
df.dtypes
# Out:
# MONTHS_BALANCE           int64
# FLAG_OWN_CAR             int64
# FLAG_OWN_REALTY          int64
# Annual_Income          float64
# Income_Type              int64
# NAME_EDUCATION_TYPE      int64
# NAME_FAMILY_STATUS       int64
# NAME_HOUSING_TYPE        int64
# Employment_Days          int64
# Occupation_Type          int64
# Family_Member_Count    float64
# Credit_Risk              int64
# dtype: object

# %%
x = df.drop('Credit_Risk',axis = 1).values
y = df['Credit_Risk'].values

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression()

# %%
model1.fit(xtrain,ytrain)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
ypred1 = model1.predict(xtest)
ypred1
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score
acc1 = accuracy_score(ytest,ypred1)
acc1 * 100
# Out:
# 99.63354185016362

# %% [markdown]
# Your Logistic Regression model achieved **99.63% accuracy**, but the convergence warning and prediction results suggest the model is likely biased toward predicting only the majority class (Good Credit Risk = 0) due to severe class imbalance in the dataset.

# %% [markdown]
# ## Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier()

# %%
model2.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
ypred2 = model2.predict(xtest)
ypred2
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
acc2 = accuracy_score(ytest,ypred2)
acc2 * 100
# Out:
# 99.64061384954643

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(ytest,ypred2)
mse
# Out:
# 0.0035938615045357234

# %% [markdown]
# The Random Forest model achieved **99.64% accuracy** with a very low mean squared error, but since the predictions are mostly class 0, the model may still be affected by the severe class imbalance in the dataset.

# %% [markdown]
# ## XG boost

# %%
from xgboost import XGBClassifier
model3 = XGBClassifier()

# %%
model3.fit(xtrain,ytrain)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
ypred3 = model3.predict(xtest)
ypred3
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
acc3 = accuracy_score(ytest,ypred3)
acc3 * 100
# Out:
# 99.68304584584328

# %% [markdown]
# The XGBoost model achieved the highest accuracy of **99.68%**, but since the predictions are still dominated by class 0, the model performance may be influenced by the severe imbalance between good and bad credit risk classes.
